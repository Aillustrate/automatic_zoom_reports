# %% [markdown]
# # Prerequisites

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -qU attrdict3 pyannote.audio python-dotenv yt_dlp
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 80.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Aillustrate/automatic_zoom_reports.git
# Out:
# Cloning into 'automatic_zoom_reports'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 65 (delta 34), reused 51 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (65/65), 13.34 KiB | 4.45 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
#%cd automatic_zoom_reports

# %%
# !git clone https://github.com/bond005/pisets.git
# Out:
# Cloning into 'pisets'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 237 (delta 33), reused 33 (delta 26), pack-reused 157 (from 1)
# Receiving objects: 100% (237/237), 66.53 MiB | 15.12 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
# !python -m pip install -r pisets/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 85.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 91.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 64.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
#os.environ['HF_TOKEN'] = <your hf token with approved access to pyannote>

# %% [markdown]
# # Usage via Python

# %%
import sys
sys.path.append("automatic_zoom_reports")
sys.path.append("pisets")
from asr.diarization import Diarizer
from asr.recognition import Recognizer
from asr.transcription import Transcription
from asr.transcriber import Transriber

# %%
from download_utils import download_video_from_youtube

#download_video_from_youtube('https://www.youtube.com/watch?v=2lPYNu01j8I')

# %%
#use this code if you get problems with encoding after downloading video
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
transriber = Transriber()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.28k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bond005/wav2vec2-large-ru-golos were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# ...

# %%
path = '/content/drive/MyDrive/zoom-summarization/Карьерная панельная дискуссия_short.mkv'
transcription = transriber.transcribe(input_path=path)
# Out:
# Extracting audio from video...
# MoviePy - Writing audio in output_audio.wav
# MoviePy - Done.
# Audio saved as output_audio.wav
# Recognizing audio...
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   0%|          | 0/11 [00:00<?, ?it/s]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
#
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 100%|██████████| 11/11 [00:18<00:00,  1.70s/it]
# ...

# %%
transcription.to_dict()
# Out:
# [{'start': 0.0,
#   'end': 39.38,
#   'text': 'Немножко расскажу, о чем у нас сегодня здесь будет разговор. Мы, как видите, сидим так, как вроде такие на панельке, для того чтобы поговорить про карьеру. Почему мы Сидим, а вы сидите там. Давайте, наверное, каждый немножко представится и расскажет, почему он здесь. Начнём с Насти. Расскажи немножко про себя. Я попрошу делать это достаточно кратко, чтобы мы много времени занимали, чтобы все понимали, кто перед аудиторией.',
#   'speaker': 'SPEAKER_00'},
#  {'start': 40.14,
#   'end': 80.82,
# ...

# %%
transcription.save_json()
# Out:
# Saved transcription to transcription.json

# %%
transcription.to_str()
# Out:
# 'SPEAKER_00 0.0 - 39.38: Немножко расскажу, о чем у нас сегодня здесь будет разговор. Мы, как видите, сидим так, как вроде такие на панельке, для того чтобы поговорить про карьеру. Почему мы Сидим, а вы сидите там. Давайте, наверное, каждый немножко представится и расскажет, почему он здесь. Начнём с Насти. Расскажи немножко про себя. Я попрошу делать это достаточно кратко, чтобы мы много времени занимали, чтобы все понимали, кто перед аудиторией.\nSPEAKER_02 40.14 - 80.82: Всем, привет! Меня зовут Настя. Я в ДС уже пять лет. Клуб анонимных алкоголиков. Большую часть времени занимаюсь NLP. В последнее время больше занимаюсь бизнес-задачами. Успела позаниматься бигдатой, успела поработать в крупных компаниях, в стартапах. В не очень крупных компаниях. Сейчас в чем-то среднем работаю. Считаю, что устаканилось. Последнее время много занимаюсь сабвесами, сабвесами в никуда. Поэтому считаю, что вроде как что-то понимаю про карьеру. Сейчас я работаю в компании «Звук». Всем привет!\nSPEAKER
# ...

# %%
transcription.save_txt()
# Out:
# Saved transcription to transcription.txt

# %%
from IPython.display import HTML, display_html

display_html(HTML(transcription.to_html()))
# Out:
# <span style='color:red'>SPEAKER_00</span> 0.0 - 39.38: Немножко расскажу, о чем у нас сегодня здесь будет разговор. Мы, как видите, сидим так, как вроде такие на панельке, для того чтобы поговорить про карьеру. Почему мы Сидим, а вы сидите там. Давайте, наверное, каждый немножко представится и расскажет, почему он здесь. Начнём с Насти. Расскажи немножко про себя. Я попрошу делать это достаточно кратко, чтобы мы много времени занимали, чтобы все понимали, кто перед аудиторией.<br><span style='color:pink'>SPEAKER_02</span> 40.14 - 80.82: Всем, привет! Меня зовут Настя. Я в ДС уже пять лет. Клуб анонимных алкоголиков. Большую часть времени занимаюсь NLP. В последнее время больше занимаюсь бизнес-задачами. Успела позаниматься бигдатой, успела поработать в крупных компаниях, в стартапах. В не очень крупных компаниях. Сейчас в чем-то среднем работаю. Считаю, что устаканилось. Последнее время много занимаюсь сабвесами, сабвесами в никуда. Поэтому считаю, что вроде как что-то понимаю про ка
# ...

# %%
transcription.save_html()
# Out:
# Saved transcription to transcription.html
